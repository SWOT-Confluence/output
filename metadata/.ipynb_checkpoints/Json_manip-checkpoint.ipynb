# %%
library(jsonlite)
OG=fromJSON('/nas/cee-water/cjgleason/colin/output/metadata/metadata.json')

# %%
OG$consensus=list(consensus_q=list(long_name='consensus_discharge',
                                   short_name='consensus',
                                   units='m^3/s',
                                   valid_min=0,
                                   valid_max=1e7,
                                   fill=-99999999,
                                   coverage_content_type='modelResult'),
                 time_str=list(long_name='time for consensus Q',
                                   short_name='time',
                                   units='time in UTC',
                                   valid_min=0,
                                   valid_max=1e7,
                                   fill='xxxxxxxxxxxxxxxxxxxx',
                                   coverage_content_type='modelResult'))

# %%
write_json(OG, '/nas/cee-water/cjgleason/colin/output/metadata/metadata.json')
